# %% [markdown]
# # Scrapping Quotes using BeautifulSoup python library
#
# --Website quotes.toscrape.com

# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
res=requests.get("http://quotes.toscrape.com/")
print(res)
# Out:
# <Response [200]>

# %%
# response object text will not give individual quotes as key elements. For that we have to use beautifulsoup.
print(res.text)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# 	<meta charset="UTF-8">
# 	<title>Quotes to Scrape</title>
#     <link rel="stylesheet" href="/static/bootstrap.min.css">
#     <link rel="stylesheet" href="/static/main.css">
# </head>
# <body>
#     <div class="container">
#         <div class="row header-box">
#             <div class="col-md-8">
#                 <h1>
#                     <a href="/" style="text-decoration: none">Quotes to Scrape</a>
#                 </h1>
#             </div>
#             <div class="col-md-4">
#                 <p>
#
#                     <a href="/login">Login</a>
#
#                 </p>
#             </div>
#         </div>
#
#
# <div class="row">
#     <div class="col-md-8">
#
#     <div class="quote" itemscope itemtype="http://schema.org/CreativeWork">
#         <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>
#         <span>by <small class="author" itemprop="author">Albert Einstein</small>
#         <a href="/author/Albert-Einstein">(about)</a>
#         </span>
#         <div class="tags">
#             Tags:
#             <meta class="keywords" itemprop="keywords" content="change,deep-thoughts,thinking,world" /    >
#
#             <a class="tag" href="/tag/change/page/1/">change</a>
#
#             <a class="tag" href="/tag/deep-thoughts/page/1/">deep-thoughts</a>
#
#             <a class="tag" href="/tag/thinking/page/1/">thinking</a>
#
#             <a class="tag" href="/tag/world/page/1/">world</a>
#
#         </div>
#     </div>
#
#     <div class="quote" itemscope itemtype="http://schema.org/CreativeWork">
#         <span class="text" itemprop="text">“It is our choices, Harry, that show what we truly are, far more than our abilities.”</span>
#         <span>by <small class="author" itemprop="author">J.K. Rowling</small>
#         <a href="/author/J-K-Rowling">(about)</a>
#         </span>
#         <div class="tags">
#             Tags:
#             <meta class="keywords" itemprop="keywords" content="abilities,choices" /    >
#
#             <a class="tag" href="/tag/abilities/page/1/">abilities</a>
#
#             <a class="tag" href="/tag/choices/page/1/">choices</a>
#
#         </div>
#     </div>
#
#     <div class="quote" itemscope itemtype="http://schema.org/CreativeWork">
#         <span class="text" itemprop="text">“There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”</span>
#         <span>by <small class="author" itemprop="author">Albert Einstein</small>
#         <a href="/author/Albert-Einstein">(about)</a>
#         </span>
#         <div class="tags">
#             Tags:
#             <meta class="keywords" itemprop="keywords" content="inspirational,life,live,miracle,miracles" /    >
#
#             <a class="tag" href="/tag/inspirational/page/1/">inspirational</a>
#
#             <a class="tag" href="/tag/life/page/1/">life</a>
#
#             <a class="tag" href="/tag/live/page/1/">live</a>
#
#             <a class="tag" href="/tag/miracle/page/1/">miracle</a>
#
#             <a class="tag" href="/tag/miracles/page/1/">miracles</a>
#
#         </div>
#     </div>
#
#     <div class="quote" itemscope itemtype="http://schema.org/CreativeWork">
#         <span class="text" itemprop="text">“The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”</span>
#         <span>by <small class="author" itemprop="author">Jane Austen</small>
#         <a href="/author/Jane-Austen">(about)</a>
#         </span>
#         <div class="tags">
#             Tags:
#             <meta class="keywords" itemprop="keywords" content="aliteracy,books,classic,humor" /    >
#
#             <a class="tag" href="/tag/aliteracy/page/1/">aliteracy</a>
#
#             <a class="tag" href="/tag/books/page/1/">books</a>
#
#             <a class="tag" href="/tag/classic/page/1/">classic</a>
#
#             <a class="tag" href="/tag/humor/page/1/">humor</a>
#
#         </div>
#     </div>
#
#     <div class="quote" itemscope itemtype="http://schema.org/CreativeWork">
#         <span class="text" itemprop="text">“Imperfection is beauty, madness is genius and it&#39;s better to be absolutely ridiculous than absolutely boring.”</span>
#         <span>by <small class="author" itemprop="author">Marilyn Monroe</small>
#         <a href="/author/Marilyn-Monroe">(about)</a>
#         </span>
#         <div class="tags">
#             Tags:
#             <meta class="keywords" itemprop="keywords" content="be-yourself,inspirational" /    >
#
#             <a class="tag" href="/tag/be-yourself/page/1/">be-yourself</a>
#
#             <a class="tag" href="/tag/inspirational/page/1/">inspirational</a>
#
#         </div>
#     </div>
#
#     <div class="quote" itemscope itemtype="http://schema.org/CreativeWork">
#         <span class="text" itemprop="text">“Try not to become a man of success. Rather become a man of value.”</span>
#         <span>by <small class="author" itemprop="author">Albert Einstein</small>
#         <a href="/author/Albert-Einstein">(about)</a>
#         </span>
#         <div class="tags">
#             Tags:
#             <meta class="keywords" itemprop="keywords" content="adulthood,success,value" /    >
#
#             <a class="tag" href="/tag/adulthood/page/1/">adulthood</a>
#
#             <a class="tag" href="/tag/success/page/1/">success</a>
#
#             <a class="tag" href="/tag/value/page/1/">value</a>
#
#         </div>
#     </div>
#
#     <div class="quote" itemscope itemtype="http://schema.org/CreativeWork">
#         <span class="text" itemprop="text">“It is better to be hated for what you are than to be loved for what you are not.”</span>
#         <span>by <small class="author" itemprop="author">André Gide</small>
#         <a href="/author/Andre-Gide">(about)</a>
#         </span>
#         <div class="tags">
#             Tags:
#             <meta class="keywords" itemprop="keywords" content="life,love" /    >
#
#             <a class="tag" href="/tag/life/page/1/">life</a>
#
#             <a class="tag" href="/tag/love/page/1/">love</a>
#
#         </div>
#     </div>
#
#     <div class="quote" itemscope itemtype="http://schema.org/CreativeWork">
#         <span class="text" itemprop="text">“I have not failed. I&#39;ve just found 10,000 ways that won&#39;t work.”</span>
#         <span>by <small class="author" itemprop="author">Thomas A. Edison</small>
#         <a href="/author/Thomas-A-Edison">(about)</a>
#         </span>
#         <div class="tags">
#             Tags:
#             <meta class="keywords" itemprop="keywords" content="edison,failure,inspirational,paraphrased" /    >
#
#             <a class="tag" href="/tag/edison/page/1/">edison</a>
#
#             <a class="tag" href="/tag/failure/page/1/">failure</a>
#
#             <a class="tag" href="/tag/inspirational/page/1/">inspirational</a>
#
#             <a class="tag" href="/tag/paraphrased/page/1/">paraphrased</a>
#
#         </div>
#     </div>
#
#     <div class="quote" itemscope itemtype="http://schema.org/CreativeWork">
#         <span class="text" itemprop="text">“A woman is like a tea bag; you never know how strong it is until it&#39;s in hot water.”</span>
#         <span>by <small class="author" itemprop="author">Eleanor Roosevelt</small>
#         <a href="/author/Eleanor-Roosevelt">(about)</a>
#         </span>
#         <div class="tags">
#             Tags:
#             <meta class="keywords" itemprop="keywords" content="misattributed-eleanor-roosevelt" /    >
#
#             <a class="tag" href="/tag/misattributed-eleanor-roosevelt/page/1/">misattributed-eleanor-roosevelt</a>
#
#         </div>
#     </div>
#
#     <div class="quote" itemscope itemtype="http://schema.org/CreativeWork">
#         <span class="text" itemprop="text">“A day without sunshine is like, you know, night.”</span>
#         <span>by <small class="author" itemprop="author">Steve Martin</small>
#         <a href="/author/Steve-Martin">(about)</a>
#         </span>
#         <div class="tags">
#             Tags:
#             <meta class="keywords" itemprop="keywords" content="humor,obvious,simile" /    >
#
#             <a class="tag" href="/tag/humor/page/1/">humor</a>
#
#             <a class="tag" href="/tag/obvious/page/1/">obvious</a>
#
#             <a class="tag" href="/tag/simile/page/1/">simile</a>
#
#         </div>
#     </div>
#
#     <nav>
#         <ul class="pager">
#
#
#             <li class="next">
#                 <a href="/page/2/">Next <span aria-hidden="true">&rarr;</span></a>
#             </li>
#
#         </ul>
#     </nav>
#     </div>
#     <div class="col-md-4 tags-box">
#
#             <h2>Top Ten tags</h2>
#
#             <span class="tag-item">
#             <a class="tag" style="font-size: 28px" href="/tag/love/">love</a>
#             </span>
#
#             <span class="tag-item">
#             <a class="tag" style="font-size: 26px" href="/tag/inspirational/">inspirational</a>
#             </span>
#
#             <span class="tag-item">
#             <a class="tag" style="font-size: 26px" href="/tag/life/">life</a>
#             </span>
#
#             <span class="tag-item">
#             <a class="tag" style="font-size: 24px" href="/tag/humor/">humor</a>
#             </span>
#
#             <span class="tag-item">
#             <a class="tag" style="font-size: 22px" href="/tag/books/">books</a>
#             </span>
#
#             <span class="tag-item">
#             <a class="tag" style="font-size: 14px" href="/tag/reading/">reading</a>
#             </span>
#
#             <span class="tag-item">
#             <a class="tag" style="font-size: 10px" href="/tag/friendship/">friendship</a>
#             </span>
#
#             <span class="tag-item">
#             <a class="tag" style="font-size: 8px" href="/tag/friends/">friends</a>
#             </span>
#
#             <span class="tag-item">
#             <a class="tag" style="font-size: 8px" href="/tag/truth/">truth</a>
#             </span>
#
#             <span class="tag-item">
#             <a class="tag" style="font-size: 6px" href="/tag/simile/">simile</a>
#             </span>
#
#
#     </div>
# </div>
#
#     </div>
#     <footer class="footer">
#         <div class="container">
#             <p class="text-muted">
#                 Quotes by: <a href="https://www.goodreads.com/quotes">GoodReads.com</a>
#             </p>
#             <p class="copyright">
#                 Made with <span class='sh-red'>❤</span> by <a href="https://scrapinghub.com">Scrapinghub</a>
#             </p>
#         </div>
#     </footer>
# </body>
# </html>

# %%
soup=BeautifulSoup(res.text,'lxml')

# %%
quote=soup.find('div',{'class' : 'quote'})

# %%
print(quote.text)
# Out:
# “The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”
# by Albert Einstein
# (about)
#
#
#             Tags:
#
# change
# deep-thoughts
# thinking
# world

# %%
quote=soup.find_all('span',{'class':'text'})

# %%
# to print all the required quotes
for q in quote:
    print(q.text)
# Out:
# “The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”
# “It is our choices, Harry, that show what we truly are, far more than our abilities.”
# “There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”
# “The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”
# “Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.”
# “Try not to become a man of success. Rather become a man of value.”
# “It is better to be hated for what you are than to be loved for what you are not.”
# “I have not failed. I've just found 10,000 ways that won't work.”
# “A woman is like a tea bag; you never know how strong it is until it's in hot water.”
# “A day without sunshine is like, you know, night.”

# %%
# to scrape author name as well
quote= soup.find_all('div',{'class':'quote'})

for q in quote:
    msg=q.find('span',{'class':'text'})
    
    print(msg.text)
    author=q.find('small')
    print("--"+author.text)
# Out:
# “The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”
# --Albert Einstein
# “It is our choices, Harry, that show what we truly are, far more than our abilities.”
# --J.K. Rowling
# “There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”
# --Albert Einstein
# “The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”
# --Jane Austen
# “Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.”
# --Marilyn Monroe
# “Try not to become a man of success. Rather become a man of value.”
# --Albert Einstein
# “It is better to be hated for what you are than to be loved for what you are not.”
# --André Gide
# “I have not failed. I've just found 10,000 ways that won't work.”
# --Thomas A. Edison
# “A woman is like a tea bag; you never know how strong it is until it's in hot water.”
# --Eleanor Roosevelt
# “A day without sunshine is like, you know, night.”
# --Steve Martin

# %% [markdown]
# # Scraping Ratings of colleges from website shiksha.com

# %%
# making response variable 
res= requests.get("https://www.shiksha.com/mba/ranking/top-mba-colleges-in-india/2-2-0-0-0")

# %%
print(res)
# Out:
# <Response [403]>

# %%
print(res.text)
# Out:
# <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access "http&#58;&#47;&#47;www&#46;shiksha&#46;com&#47;mba&#47;ranking&#47;top&#45;mba&#45;colleges&#45;in&#45;india&#47;2&#45;2&#45;0&#45;0&#45;0" on this server.<P>
# Reference&#32;&#35;18&#46;57db0d17&#46;1550124541&#46;49edf3a4
# </BODY>
# </HTML>

# %%
# Headers from web page

headers = {

   "User-Agent": "Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:65.0) Gecko/20100101 Firefox/65.0"
}
r = requests.get("https://www.shiksha.com/mba/ranking/top-mba-colleges-in-india/2-2-0-0-0", headers = headers)

# %%
print(r.text)
# Out:
# <!Doctype html>
# <html>
# <head>
# 	<meta charset="utf-8"/>
# 	<meta http-equiv="X-UA-Compatible" content="IE=edge"/>
# 	<title data-reactroot="">Top MBA Colleges in india 2019 - Ranks, Fees, Cut-off, Placement</title><meta name="keywords" content="Shiksha, education, colleges,universities, institutes,career, career options, career prospects,engineering, mba, medical, mbbs,study abroad, foreign education, college, university, institute,courses, coaching, technical education, higher education,forum, community, education career experts,ask experts, admissions,results, events,scholarships" data-reactroot=""/><meta name="description" content="For 326 MBA colleges - Get 2019 rankings , placement reviews, courses and Q&amp;A related to admission, cut-off and eligibility for Top MBA colleges in india. The rankings are from MHRD-NIRF, The Week, and Business Today. You can compare best MBA colleges in india." data-reactroot=""/><link rel="canonical" href="https://www.shiksha.com/mba/ranking/top-mba-colleges-in-india/2-2-0-0-0" data-reactroot=""/><link rel="next" href="https://www.shiksha.com/mba/ranking/top-mba-colleges-in-india/2-2-0-0-0?pageNo=2" data-reactroot=""/>
# 	<meta name="copyright" content="Shiksha.com">
# 	<meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
# 	<meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1"/>
# 	<link rel="dns-prefetch" href="//js.shiksha.ws"/>
# 	<link rel="dns-prefetch" href="//css.shiksha.ws"/>
# 	<link rel="dns-prefetch" href="//images.shiksha.ws"/>
# 	<link rel="dns-prefetch" href="//images.shiksha.com"/>
#     <link rel="dns-prefetch" href="//track.shiksha.com"/>
# 	<link rel="preconnect" href="//js.shiksha.ws" />
# 	<link rel="preconnect" href="//css.shiksha.ws" />
# 	<link rel="preconnect" href="//images.shiksha.com" />
# 	<style>
#     html{-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;font-family:'Open Sans',Arial,sans-serif}:root{font-size:16px}*{margin:0;padding:0;border:0;box-sizing:border-box}.pwa_container{width:1170px;margin:0 auto}.pwa_container:after{content:"";display:block;clear:both}.pwa_leftCol{width:770px;float:left;padding-right:15px}.pwa_rightCol{width:370px;float:left;padding-left:15px}.n-headerP *,footer *{-webkit-box-sizing:border-box;-moz-box-sizing:border-box;box-sizing:border-box;font-family:'Open Sans',sans-serif}.n-headerP ol,ul,footer ol,footer ul{list-style:none}.n-headerP input:focus{outline:0}.n-headerP a,.n-headerP a:hover,footer a,footer a:hover{outline:0;text-decoration:none}article,aside,footer,header,hgroup,main,nav,section{display:block}.rowL{margin-left:-20px;margin-right:0}.rowR{margin-left:0;margin-right:-20px}.row:after,.row:before{content:"";clear:both;display:table}.container{padding-right:16px;padding-left:16px;margin-right:auto;margin-left:auto;-webkit-box-sizing:border-box;-moz-box-sizing:border-box;box-sizing:border-box}@media(min-width: 768px){.container{width:750px}}@media(min-width: 992px){.container{width:928px}}@media(min-width: 1200px){.container{width:928px}}#wrapperMainForCompleteShiksha{min-width:1250px;overflow-x:auto}#wrapperMainForCompleteShiksha.onlineForm{overflow-x:hidden!important}.container-fluid{padding-right:16px;padding-left:16px;margin-right:auto;margin-left:auto}.n-row{margin-right:-16px;margin-left:-16px}.col-xs-1,.col-sm-1,.col-md-1,.col-lg-1,.col-xs-2,.col-sm-2,.col-md-2,.col-lg-2,.col-xs-3,.col-sm-3,.col-md-3,.col-lg-3,.col-xs-4,.col-sm-4,.col-md-4,.col-lg-4,.col-xs-5,.col-sm-5,.col-md-5,.col-lg-5,.col-xs-6,.col-sm-6,.col-md-6,.col-lg-6,.col-xs-7,.col-sm-7,.col-md-7,.col-lg-7,.col-xs-8,.col-sm-8,.col-md-8,.col-lg-8,.col-xs-9,.col-sm-9,.col-md-9,.col-lg-9,.col-xs-10,.col-sm-10,.col-md-10,.col-lg-10,.col-xs-11,.col-sm-11,.col-md-11,.col-lg-11,.col-xs-12,.col-sm-12,.col-md-12,.col-lg-12{position:relative;min-height:1px;padding-right:16px;padding-left:16px;-webkit-box-sizing:border-box;-moz-box-sizing:border-box;box-sizing:border-box}.col-xs-1,.col-xs-2,.col-xs-3,.col-xs-4,.col-xs-5,.col-xs-6,.col-xs-7,.col-xs-8,.col-xs-9,.col-xs-10,.col-xs-11,.col-xs-12{float:left}.col-lg-1,.col-lg-2,.col-lg-3,.col-lg-4,.col-lg-5,.col-lg-6,.col-lg-7,.col-lg-8,.col-lg-9,.col-lg-10,.col-lg-11,.col-lg-12{float:left}.col-lg-12{width:100%}.col-lg-11{width:91.66666667%}.col-lg-10{width:83.33333333%}.col-lg-9{width:75%}.col-lg-8{width:66.66666667%}.col-lg-7{width:58.33333333%}.col-lg-6{width:50%}.col-lg-5{width:41.66666667%}.col-lg-4{width:33.33333333%}.col-lg-3{width:25%}.col-lg-2{width:16.66666667%}.col-lg-1{width:8.33333333%}.pLR0{padding-left:0;padding-right:0}.pL0{padding-left:0}.pR0{padding-right:0}.pT0{padding-top:0}.pB0{padding-bottom:0}.p00{padding:0}.pL20{padding-left:20px}.mLR0{margin-left:0;margin-right:0}.mL0{margin-left:0}.mR0{margin-right:0}.mT0{margin-top:0}.mB0{margin-bottom:0}.m00{margin:0}.mB32{margin-bottom:32px}.fLeft{float:left}.fRight{float:right}.clr{clear:both;display:block;height:0;width:100%}.wrapper{max-width:928px;width:100%;margin:auto;background:#fff;border-left:1px solid #efefef;border-right:1px solid #efefef}.h1{color:#404041;font-size:24px;font-weight:600}.h2{color:#404041;font-size:19px;font-weight:600}.h3{color:#6d6e70;font-size:19px;font-weight:600}.p1{color:#404041;font-size:14px;font-weight:100}.p2{color:#808184;font-size:14px;font-weight:400}.p3{color:#404041;font-size:14px;font-weight:700}.p4{color:#808184;font-size:12px;font-weight:400}.a1{color:#231f20;font-size:14px;font-weight:400}.a2{color:#05828d;font-size:14px;font-weight:400}.a3{color:#808184;font-size:14px;font-weight:400}.icons{background-image:url(https://images.shiksha.ws/pwa/public/images/desktop/shiksha-icons-sprite-2.png);background-repeat:no-repeat;display:inline-block}.ic_down{width:9px;height:5px;background-position:0 0}.ic_student{width:16px;height:17px;background-position:-231px  ...
#      /*latest gnb css */ .inside-gnbpage {position: absolute;width: 790px;margin: 0 auto;left: -124px;top: 10px;z-index: 11;right: 0;}  .inside-gnbpage .pwadesktop-srchbox{width: 100%;padding: 7px 10px 7px 15px}  .inside-gnbpage .srchBtnv1{height: 37px;} .srchBtnv1{cursor: pointer;border: none;position: absolute;right: 0;font-size: 1rem;font-weight: 600;top: 0px;color: #fff;height: 44px;border-top-right-radius: 2px;background: #f37921;outline: none;width: 110px;border-bottom-right-radius: 2px;text-shadow: 1px 1px 3px rgba(0,0,0,0.3);} .pwadesktop-srchbox{cursor: pointer;padding: 10px 10px 10px 15px;line-height: 23px;background: #fff;color: #666;border-radius: 2px;position: relative;font-size: 14px;box-shadow: 0 2px 5px 0 rgba(0,0,0,0.20), 0 0 1px 0 rgba(0,0,0,0.81);}
#         /*--END--*/
# 	.pwa-lyr.bcglayer.recoHdng p{line-height:20px}.pwa-lyr.bcglayer.recoHdng .pwa-hd{height:58px}.pwa-lyr.bcglayer.recoHdng .pwa-hd p{text-overflow:clip;white-space:normal}.pwa-lyr.bcglayer.recoHdng a.lyr-crs{line-height:58px}#fullLayer-container .ctp-SrpBtnDiv a.ctp-btn{font-size:.8125rem}.pwa-anim-lyr{-webkit-animation:listAnim .5s cubic-bezier(.4,0,.2,1),transform .5s cubic-bezier(.4,0,.2,1),-webkit-transform .5s cubic-bezier(.4,0,.2,1) forwards;animation:listAnim .5s cubic-bezier(.4,0,.2,1),transform .5s cubic-bezier(.4,0,.2,1),-webkit-transform .5s cubic-bezier(.4,0,.2,1) forwards}.small-loader{border-radius:50%;height:40px;width:40px;-moz-box-shadow:0 0 8px 2px #b5b5b5;position:fixed;top:50%;left:50%;margin:-20px 0 0 -20px}.pwa-hd{background:#008489;color:#fff;font-size:1rem;padding:10px;position:relative;height:45px;line-height:24px}.pwa-lyr{background:#fff;position:fixed;top:0;left:0;right:0;bottom:0;z-index:9}.pwa-lyr.bcglayer.reg-lyr{overflow-y:scroll}.ctp_container a.lyr-crs,.lyr-crs{float:right;font-size:1.875rem;color:#fff;text-decoration:none;line-height:44px;position:absolute;top:0;right:0;width:45px;text-align:center}.clr{clear:both}.pwa-lyrSrc{background:#d6d6d6;border-bottom:1px solid #ccc;font-size:.75rem;padding:8px;position:relative}.pwa-lyrSrc input[type=text]{width:100%;border:none;outline:0;background:#f9f9f9;height:32px;line-height:32px;padding:0 5px 0 37px}.pwa-lyrSrc.crsSrc input[type=text]{padding:0 25px 0 37px}i.search-ico{background:url(https://images.shiksha.ws/pwa/public/images/mhome-icons-sprite_3.svg) no-repeat}.pwa-lyrSrc i.search-ico{position:absolute;display:inline-block;height:20px;width:20px;background-position:-519px -106px;top:12px;left:16px}.pwa-cont{color:#000;font-size:.75rem;height:calc(100% - 40px);height:-webkit-calc(100% - 40px);overflow-y:auto}.pad{padding:15px 10px}.pwa-cont strong{font-weight:600;display:block;margin-bottom:5px;font-size:.875rem}.pwa-hd p.flLt{float:left;font-weight:600;width:92%;text-overflow:ellipsis;white-space:nowrap;overflow:hidden}.close-tip{position:fixed;z-index:4;top:-35px;right:3px;width:10px;height:20px;color:#fff;font-size:1.375rem;font-style:normal}.r-table .subcat-dtls .edit-stream{float:right;color:#fff;font-size:.625rem;text-transform:capitalize;padding:32px 10px 15px 0;position:absolute;right:-10px;top:-30px}.nrml-link{font-size:.875rem;color:#008489;display:inline-block;cursor:pointer;text-decoration:none}.word-wrap{word-break:break-word}.ui-header-fixed{top:0;padding-top:0;left:0;right:0;width:100%;position:relative;z-index:7}#root a{text-decoration:none}.ctp_container a.lyr-crs,lyr-crs{float:right;font-size:1.875rem;color:#fff;text-decoration:none;line-height:44px;position:absolute;top:0;right:0;width:45px;text-align:center}@media screen and (min-width:1024px){.tbl-seo{color:#000;font-size:14px;line-height:21px;max-height:400px;overflow:auto;background:#fff}.tbl-seo table tr td:first-child,.tbl-seo tr th:first-child{text-align:left}.tbl-seo table tr td,.tbl-seo tr th{border:1px solid #eee;border-collapse:collapse;padding:5px;text-align:center}.tbl-seo table tr th{font-weight:600;text-align:center}#fullLayer-container{background:rgba(0,0,0,.7);position:fixed;width:100%;height:100%;z-index:8;overflow:auto;display:none;top:0}#fullLayer-container.show{display:block}.pwa-lyr{top:50%;left:50%;right:auto;bottom:auto;z-index:9;max-width:500px;transform:translate(-50%,-50%);height:300px;width:100%}body.noscroll{overflow:hidden}.pwa-lyr.ext-layer{max-width:960px;height:470px}.pwa-lyr.ext-layer .tbl-seo{max-height:400px;overflow:inherit;height:100%;padding:0 15px 15px 0}.tbl-seo table{width:100%;margin-top:10px;border:1px solid #eee;border-collapse:collapse}.pwa-lyr.ext-layer .pwa-cont.pad{padding:10px 0 0 15px}.tbl-seo table{white-space:inherit;overflow:initial}}.pagnation-col{display:block;background:transparent;padding:12px 0;text-align:center;margin-bottom:5px;width:100%}.pagniatn-ul{display:inline-block;list-style:none}.pagniatn-ul li{float:left}.pa ...
# 	</style>
# 	<link rel="stylesheet" type="text/css" id="shkCmn">
#
#         <link rel="preload" href="https://css.shiksha.ws/pwa/public/js/RankingPageDesktop.1a8ac8982f382518d46c.css" as="style">
#
# 	<div id="extraCss"></div>
#
# 		<script type='text/javascript' crossorigin async src='https://js.shiksha.ws/public/js/build/pwa-desktop-common-search.min.5e616f.js'></script>
#
# 		<script type='text/javascript' crossorigin async src='https://js.shiksha.ws/public/js/build/pwa-desktop-common-regn.min.f61744.js'></script>
#
#
# 		<link rel="preload" href="https://js.shiksha.ws/pwa/public/js/RankingPageDesktop.21bb35d0bc6ef5fed9ed.js" as="script">
#
#
# 	<script type="application/ld+json">
#     {
#       "@context" : "http://schema.org",
#       "@type"    : "Organization",
#       "url"      : "https://www.shiksha.com",
#       "logo"     : "https://www.shiksha.com/public/images/nshik_ShikshaLogo1.gif",
#       "name"     : "Shiksha.com",
#       "sameAs"   : ["https://www.facebook.com/shikshacafe", "https://twitter.com/ShikshaDotCom", "https://en.wikipedia.org/wiki/Shiksha.com", "https://plus.google.com/+shiksha"]
#     }
#     </script>
# <script>bazadebezolkohpepadr="493210558"</script><script type="text/javascript" src="https://www.shiksha.com/akam/10/1d65c8be" defer></script></head>
# <body id="wrapperMainForCompleteShiksha">
# 	<div id="fullLayer-container"></div><div id="searchLayer"></div><div id="root"><div class="dfp_flexi_add"><div></div></div><header id="page-header" class="header"><div class="n-headerP innerpage-header" id="_globalNav"><div class="shiksha-navCut"></div><div class="n-header"><div class="n-logo"><a href="https://www.shiksha.com" title="Shiksha.com"><i class="icons ic_logo ic_logo_prefix"></i><i class="icons ic_logo"></i></a></div><div class="inside-gnbpage"><a><div class="pwadesktop-srchbox">Search Colleges, Courses, Exams, QnA, &amp; Articles<button type="button" name="button" class="srchBtnv1">Search</button></div></a></div><div class="global-wrapper" id="_innerNav"><ul class="nav"><li class="g_lev1"><a lang="MBA">MBA<div class="spaceWrpr"></div><em class="g_pointer"></em></a><div class="submenu"><ul class="g_lev2"><li key="Popular Courses"><a href="javascript:void(0)" class="pntr">Popular Courses</a><div class="submenu2"><table border="0"> <tr> <td> <ul class="g_lev3"> <li > <a relative="true"href='/mba-masters-of-business-administration-chp' > MBA/PGDM</a> </li> <li > <a relative="true"href='/executive-mba-pgdm-chp' > Executive MBA/PGDM</a> </li> <li > <a relative="true"href='/distance-mba-pgdm-chp' > Distance MBA</a> </li> <li > <a relative="true"href='/online-mba-pgdm-chp' > Online MBA</a> </li> <li > <a relative="true"href='/part-time-mba-pgdm-chp' > Part-Time MBA</a> </li> </ul> </td> </tr> <tr class="lastTrTd"><td></td></tr> </table></div></li> <li key="Exams"><a href="javascript:void(0)" class="pntr">Exams</a><div class="submenu2"><table border="0"> <tr> <td> <ul class="g_lev3"> <li class="head_cours"> Popular Exams </li> <li > <a href='https://www.shiksha.com/mba/cat-exam' > CAT</a> </li> <li > <a href='https://www.shiksha.com/mba/cmat-exam' > CMAT</a> </li> <li > <a href='https://www.shiksha.com/mba/snap-exam' > SNAP</a> </li> <li > <a href='https://www.shiksha.com/mba/xat-exam' > XAT</a> </li> <li > <a href='https://www.shiksha.com/mba/mat-exam' > MAT</a> </li> <li > <a href='https://www.shiksha.com/mba/atma-exam' > ATMA</a> </li> <li > <a href='https://www.shiksha.com/mba/nmat-by-gmac-exam' > NMAT by GMAC</a> </li> <li > <a href='https://www.shiksha.com/mba/exams-pc-101' class='linkk'>>  All MBA Exams</a> </li> <li > <a href='https://www.shiksha.com/mba/resources/exam-calendar' class='linkk'>>  Exam Calendar</a> </li> </ul> </td> <td> </td> </tr> <tr class="lastTrTd"><td></td> <td></td></tr> </table></div></li> <li key="Colleges by Location"><a href="javascript:void(0)" class="pntr">Colleges by Location</a><div class="submenu2"><table border="0"> <tr> <td> <ul class="g_lev3"> <li > <a relative="true"href='/mba/colleges/mba-colleges-india' > MBA Colleges in India</a> </li> <li > <a relative="true"href='/mba/colleges/mba-colleges-bangalore' > MBA Colleges in Bangalore</a> </li> <li > <a relative="true"href='/mba/colleges/mba-colleges-chennai' > MBA Colleges in Chennai</a> </li> <li > <a relative="true"href='/mba/colleges/mba-colleges-delhi-ncr' > MBA colleges in Delhi-NCR</a> </li> <li > <a relative="true"href='/mba/colleges/mba-colleges-hyderabad' > MBA Colleges in Hyderabad</a> </li> <li > <a relative="true"href='/mba/colleges/mba-colleges-kolkata' > MBA Colleges in Kolkata</a> </li> <li > <a relative="true"href='/mba/colleges/mba-colleges-mumbai-all' > MBA Colleges in Mumbai</a> </li> <li > <a relative="true"href='/mba/colleges/mba-colleges-pune' > MBA Colleges in Pune</a> </li> <li > <a relative="true"href='/mba/colleges/mba-colleges-india' class='linkk'>>  All Locations</a> </li> </ul> </td> </tr> <tr class="lastTrTd"><td></td></tr> </table></div></li> <li key="Top Colleges"><a href="javascript:void(0)" class="pntr">Top Colleges</a><div class="submenu2"><table border="0"> <tr> <td> <ul class="g_lev3"> <li class="head_cours"> Popular Colleges </li> <li > <a href='https://www.shiksha.com/college/indian-institute-of-management-ahmedabad-vastrapur-307' > IIM Ahmedabad</a> </li> <li > <a href='https://www.shiksha.co ...
# 	<div id="signUpForm"></div>
# 	<div id="popup-container"></div>
#
# 	<input type="hidden" id="shiksha_auth_token" name="shiksha_auth_token" value="fMS7M6Uc-N3bZSMqzi7JTxDh6_Kff3r6gOnM" />
# 	<script type="text/javascript">
# 		function lazyLoadJs(e,a,r){for(var s,t,c=[],d=e.scripts[0];s=r.shift();)t=e.createElement(a),"async"in d?(t.async=!1,e.head.appendChild(t)):d.readyState?(c.push(t),t.onreadystatechange=n):e.write("<"+a+' src="'+s+'" defer></'+a+">"),t.src=s}
# 		var shikshaMain = 'https://js.shiksha.ws/pwa/public/js/desktop-shiksha-main-6456fe1bc1c4abcc1583.js';
# 		var vendorMain = 'https://js.shiksha.ws/pwa/public/js/vendors.56791c3c8287af6f760f.js';
# 		var commonCss = "https://css.shiksha.ws/pwa/public/css/build/shikshaDesktopCommon.min.2ff14f.css";
#
#         function insertHeadSection(file) {
#             var scrp = document.createElement('link');
#             scrp.rel = 'preload';
#             scrp.as = 'script';
#             scrp.href = file;
#             document.head.appendChild(scrp);
#         }
#         insertHeadSection(shikshaMain);
#         insertHeadSection(vendorMain);
#
# 		var extra_css = "<link type='text/css' rel='stylesheet' href='https://css.shiksha.ws/public/css/build/pwa-desktop-extra-css.min.c13bd1.css'></link>";
# 		var referrer = '';
# 		var validDomains = [];
#
# 		validDomains.push('@gmail.com');
#
# 		validDomains.push('@yahoo.com');
#
# 		validDomains.push('@yahoo.co.in');
#
# 		validDomains.push('@rediffmail.com');
#
# 		validDomains.push('@hotmail.com');
#
# 		window.addEventListener("load", function() {
# 				lazyLoadJs(document, "script", ["https://js.shiksha.ws/pwa/public/js/RankingPageDesktop.21bb35d0bc6ef5fed9ed.js"]);
# 				lazyLoadJs(document,"script",[shikshaMain,vendorMain]);
# 				$j = jQuery.noConflict();
# 				var registrationForm          = new window.RegistrationForm();
# 				var registrationFormAjax      = new window.RegistrationFormAjax();
# 				var userRegistrationRequest   = new window.UserRegistrationRequest();
# 				var registrationFormValidator = new window.RegistrationFormValidator();
# 				var responseForm              = new window.ResponseForm();
# 				var responseFormTest          = new window.ResponseFormTest();
# 		});
# 		if (typeof commonCss == 'string') {
# 			if (document.getElementById('shkCmn') && document.getElementById('shkCmn').href == '') {
# 				document.getElementById('shkCmn').href = commonCss;
# 			}
# 		}
# 		if (typeof extra_css == 'string') {
# 			if (document.getElementById('extraCss')) {
# 				document.getElementById('extraCss').innerHTML = extra_css;
# 			}
# 		}
# 	</script>
# 	<script type="text/javascript">
#     window.__PRELOADED_STATE__ = {"config":{"PROTOCOL":"https://","EXAM_SERVICE_PORT":9005,"LISTING_SERVICE_PORT":9002,"PRED_SERVICE_PORT":9012,"DEFAULT_PORT":9014,"API_SERVER":"apis.shiksha.jsb9.net","API_SERVER_CALL":true,"CLP_PRODUCT_ID":"0010004","SHIKSHA_HOME":"https://www.shiksha.com","BEACON_SHIKSHA_HOME":"https://track.shiksha.com","SHIKSHA_STUDYABROAD_HOME":"https://studyabroad.shiksha.com","SHIKSHA_ASK_HOME":"https://ask.shiksha.com","BEACON_TRACK_URL":"https://track.shiksha.com/beacon/Beacon/track","BEACON_INDEX_TRACK_URL":"https://track.shiksha.com/beacon/Beacon/index","IMAGES_SHIKSHA":"https://images.shiksha.com","COOKIE_DOMAIN":".shiksha.com","JS_DOMAIN":"https://js.shiksha.ws","CSS_DOMAIN":"https://css.shiksha.ws","IMG_DOMAIN":"https://images.shiksha.ws"},"hpdata":{},"courseData":{},"instituteData":{},"rankingPageData":{"rankingPageId":2,"rankingPageName":"MBA","disclaimer":"\u003cp>Get rankings, placement reviews, courses and Q&A related to admission, cut-off and eligibility . The rankings are published by NIRF/MHRD, India Today, The Week.  '--' implies that the college is not ranked by the respective publications.\u003c/p>","seoData":{"heading":"Top MBA Colleges in india","canonicalUrl":"/mba/ranking/top-mba-colleges-in-india/2-2-0-0-0","metaTitle":"Top MBA Colleges in india 2019 - Ranks, Fees, Cut-off, Placement","metaDescription":"For 326 MBA colleges - Get 2019 rankings , placement reviews, courses and Q&A related to admission, cut-off and eligibility for Top MBA colleges in india. The rankings are from MHRD-NIRF, The Week, and Business Today. You can compare best MBA colleges in india.","metaKeywords":null,"prevUrl":null,"nextUrl":"/mba/ranking/top-mba-colleges-in-india/2-2-0-0-0?pageNo=2"},"show404":false,"redirectUrl":null,"numberOfResultsFound":317,"selectedRankingSource":null,"resetUrl":"/mba/ranking/top-mba-colleges-in-india/2-2-0-0-0","rankingRequestData":{"appliedFilters":{"streams":[1],"baseCourse":[101],"educationType":[20],"deliveryMethod":[0],"credential":[0],"exam":[0],"state":[0],"city":[0],"substreams":[0],"specializations":[0],"qerUsed":false,"anyEntityMatchedByQer":false,"rankingPageIds":[2],"rankingSourceIds":[27]},"removedFilters":null,"pageLimit":20,"pageNumber":1,"deviceType":"mobile","lazyLoad":false,"requestFrom":"direct"},"aggregateRatingConfig":{"aggregateRatingDisplayOrder":{"avgSalaryPlacementRating":"Placements","campusFacilitiesRating":"Infrastructure","facultyRating":"Faculty & Course Curriculum","crowdCampusRating":"Crowd & Campus Life","moneyRating":"Worth the Money"},"intervalsDisplayOrder":{"4-5":">4-5","3-4":">3-4","2-3":">2-3","1-2":"1-2"},"ratingIdToDisplayNameMapping":{"1":"Worth the Money","2":"Crowd & Campus Life","3":"Placements","4":"Infrastructure","5":"Faculty & Course Curriculum","6":"Infrastructure","7":"Placements","8":"Infrastructure","9":"Infrastructure","10":"Placements"}},"rankingInstituteTuple":[{"instituteId":307,"name":"IIM Ahmedabad - Indian Institute of Management (IIMA)","url":"/college/iim-ahmedabad-indian-institute-of-management-iima-vastrapur-307","headerImage":"https://images.shiksha.com/mediadata/images/1505365788phpXJ5Yga_100x78.jpg","location":"Ahmedabad","admissionUrl":"/college/iim-ahmedabad-indian-institute-of-management-iima-vastrapur-307/admission","courseData":{"courseId":1653,"allCourseUrl":"/college/iim-ahmedabad-indian-institute-of-management-iima-vastrapur-307/courses","courseCount":5},"reviewData":{"url":"/college/iim-ahmedabad-indian-institute-of-management-iima-vastrapur-307/reviews","aggregateReviewData":{"totalCount":17,"aggregateRating":{"averageRating":{"count":17,"sum":75.6,"mean":4.4},"facultyRating":{"count":17,"sum":75,"mean":4.4},"campusFacilitiesRating":{"count":17,"sum":81,"mean":4.8},"avgSalaryPlacementRating":{"count":17,"sum":72,"mean":4.2},"crowdCampusRating":{"count":17,"sum":74,"mean":4.4},"moneyRating":{"count":17,"sum":76,"mean":4.5}},"intervalRatingCount":{"1-2":0,"2-3":2,"3-4":2,"4-5":13}}},"instituteExtraData" ...
#     window.serviceWokrerFile = "service-worker.e8eae4.js";
#     window.COOKIEDOMAIN = ".shiksha.com";
#     window.sessionID = "te5Cap1iJ1sjYO-3LrneeBMcKOvzEpBO";
# 		window.isUserLoggedIn = false;
# 		window.isHeaderFixed = true;
# 		window.isCompareEnable = false;
# 		window.shikshaProduct = 'default';
# 		window.productPage = 'default';
#   </script>
# <noscript><img src="https://www.shiksha.com/akam/10/pixel_1d65c8be?a=dD0wMTlhYWM1MjQzNWNkNzllNTU0OTIzNDNiMTNkOTc0MWQ0ZmUyYzA1JmpzPW9mZg==" style="visibility: hidden; position: absolute; left: -999px; top: -999px;" /></noscript></body>
# <script>
#   (function (i, s, o, g, r, a, m) {
#     i['GoogleAnalyticsObject'] = r;
#     i[r] = i[r] || function () {
#       (i[r].q = i[r].q || []).push(arguments);
#     }, i[r].l = 1 * new Date();
#     a = s.createElement(o),
#       m = s.getElementsByTagName(o)[0];
#     a.async = 1;
#     a.src = g;
#     m.parentNode.insertBefore(a, m);
# })(window, document, 'script',  'https://www.google-analytics.com/analytics.js', 'ga');
# </script>
# </html>

# %%
soup=BeautifulSoup(r.content)
# print(r.content)
# print(soup)

# %%
# Scratching ratings of colleges 
for section in soup.findAll('section', attrs={"class":'rank_tuplev1'}):
    rating= section.find('span',attrs={'class':'rating-block rvw-lyr'})
    print(rating.text)
# Out:
# 4.4Placements4.2Infrastructure4.8Faculty & Course Curriculum4.4Crowd & Campus Life4.4Worth the Money4.5View all 17 reviews
#
# 4.7Placements4.8Infrastructure4.6Faculty & Course Curriculum4.7Crowd & Campus Life4.8Worth the Money4.8View all 13 reviews
#
# 4.7Placements4.9Infrastructure4.4Faculty & Course Curriculum4.6Crowd & Campus Life4.8Worth the Money4.7View all 30 reviews
#
# 4.5Placements4.5Infrastructure4.7Faculty & Course Curriculum4.2Crowd & Campus Life4.6Worth the Money4.7View all 35 reviews
#
# 4.4Placements4.8Infrastructure3.5Faculty & Course Curriculum4.4Crowd & Campus Life4.2Worth the Money5.0View all 69 reviews
#
# 4.4Placements4.2Infrastructure4.3Faculty & Course Curriculum4.3Crowd & Campus Life4.7Worth the Money4.3View all 26 reviews
#
# 4.5Placements4.5Infrastructure4.6Faculty & Course Curriculum4.4Crowd & Campus Life4.8Worth the Money4.4View all 22 reviews
#
# 4.4Placements4.2Infrastructure4.6Faculty & Course Curriculum3.9Crowd & Campus Life4.7Worth the Money4.4View all 188 reviews
#
# 4.2Placements3.9Infrastructure4.4Faculty & Course Curriculum4.3Crowd & Campus Life4.5Worth the Money4.0View all 110 reviews
#
# 4.5Placements4.3Infrastructure4.5Faculty & Course Curriculum4.3Crowd & Campus Life4.4Worth the Money4.8View all 27 reviews
#
# 4.7Placements4.6Infrastructure4.8Faculty & Course Curriculum4.5Crowd & Campus Life4.8Worth the Money4.8View all 55 reviews
#
# 4.4Placements4.6Infrastructure4.2Faculty & Course Curriculum4.4Crowd & Campus Life4.4Worth the Money4.4View all 68 reviews
#
# 4.6Placements4.8Infrastructure4.1Faculty & Course Curriculum4.3Crowd & Campus Life4.6Worth the Money4.9View all 31 reviews
#
# 4.4Placements4.2Infrastructure4.8Faculty & Course Curriculum4.6Crowd & Campus Life4.0Worth the Money4.3View all 25 reviews
#
# 4.8Placements4.3Infrastructure5.0Faculty & Course Curriculum4.8Crowd & Campus Life4.8Worth the Money5.0View all 4 reviews
#
# 4.3Placements3.7Infrastructure4.7Faculty & Course Curriculum4.8Crowd & Campus Life4.4Worth the Money3.9View all 44 reviews
#
# 4.1Placements4.0Infrastructure3.7Faculty & Course Curriculum4.3Crowd & Campus Life4.2Worth the Money4.2View all 26 reviews
#
# 4.4Placements4.1Infrastructure4.3Faculty & Course Curriculum4.4Crowd & Campus Life4.4Worth the Money4.5View all 16 reviews
#
# 4.5Placements4.6Infrastructure4.3Faculty & Course Curriculum3.9Crowd & Campus Life4.6Worth the Money4.9View all 12 reviews
#
# 4.3Placements4.3Infrastructure4.7Faculty & Course Curriculum3.9Crowd & Campus Life4.7Worth the Money4.1View all 55 reviews
