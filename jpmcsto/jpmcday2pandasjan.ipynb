# %%
import pandas as pd

# %%
s1 = pd.Series([10,20,30])

# %%
s1
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
s2 = pd.Series([50,60,70])

# %%
s2
# Out:
# 0    50
# 1    60
# 2    70
# dtype: int64

# %%
df1 = pd.DataFrame({"col1":s1,"col2":s2})

# %%
df1
# Out:
#    col1  col2
# 0    10    50
# 1    20    60
# 2    30    70

# %%
iris=pd.read_csv("https://raw.githubusercontent.com/vishurudratrainer/notebooks/main/jpmcsto/datasets-master/Iris.csv")

# %%
iris =pd.read_csv("C://data/Iris.csv")

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.head(7)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa

# %%
iris.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
iris.shape
# Out:
# (150, 6)

# %%
iris.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers.readers:
#
# ...

# %%
irisindex=iris =pd.read_csv("C://data/Iris.csv",index_col=None)

# %%
irisindex.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
iris['SepalLengthCm']
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: SepalLengthCm, Length: 150, dtype: float64

# %%
iris[['SepalLengthCm','SepalWidthCm']]
# Out:
#      SepalLengthCm  SepalWidthCm
# 0              5.1           3.5
# 1              4.9           3.0
# 2              4.7           3.2
# 3              4.6           3.1
# 4              5.0           3.6
# ..             ...           ...
# 145            6.7           3.0
# 146            6.3           2.5
# 147            6.5           3.0
# 148            6.2           3.4
# 149            5.9           3.0
#
# [150 rows x 2 columns]

# %%
iriswithoutId = iris.drop('Id',axis=1) #dropping column
iriswithoutId.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.drop('Id',axis=1,inplace=True)

# %%
iris.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.columns=iris.columns.str.lower()

# %%
iris.head()
# Out:
#    sepallengthcm  sepalwidthcm  petallengthcm  petalwidthcm      species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris['species']=iris['species'].str.upper()

# %%
iris.head()
# Out:
#    sepallengthcm  sepalwidthcm  petallengthcm  petalwidthcm      species
# 0            5.1           3.5            1.4           0.2  IRIS-SETOSA
# 1            4.9           3.0            1.4           0.2  IRIS-SETOSA
# 2            4.7           3.2            1.3           0.2  IRIS-SETOSA
# 3            4.6           3.1            1.5           0.2  IRIS-SETOSA
# 4            5.0           3.6            1.4           0.2  IRIS-SETOSA

# %%
#iloc

#iris.iloc[rownumber   , columnumber  ]

iris.iloc[35:50]
# Out:
#     sepallengthcm  sepalwidthcm  petallengthcm  petalwidthcm      species
# 35            5.0           3.2            1.2           0.2  IRIS-SETOSA
# 36            5.5           3.5            1.3           0.2  IRIS-SETOSA
# 37            4.9           3.1            1.5           0.1  IRIS-SETOSA
# 38            4.4           3.0            1.3           0.2  IRIS-SETOSA
# 39            5.1           3.4            1.5           0.2  IRIS-SETOSA
# 40            5.0           3.5            1.3           0.3  IRIS-SETOSA
# 41            4.5           2.3            1.3           0.3  IRIS-SETOSA
# 42            4.4           3.2            1.3           0.2  IRIS-SETOSA
# 43            5.0           3.5            1.6           0.6  IRIS-SETOSA
# 44            5.1           3.8            1.9           0.4  IRIS-SETOSA
# 45            4.8           3.0            1.4           0.3  IRIS-SETOSA
# 46            5.1           3.8            1.6           0.2  IRIS-SETOSA
# ...

# %%
iris.iloc[35:50,0:2]
# Out:
#     sepallengthcm  sepalwidthcm
# 35            5.0           3.2
# 36            5.5           3.5
# 37            4.9           3.1
# 38            4.4           3.0
# 39            5.1           3.4
# 40            5.0           3.5
# 41            4.5           2.3
# 42            4.4           3.2
# 43            5.0           3.5
# 44            5.1           3.8
# 45            4.8           3.0
# 46            5.1           3.8
# 47            4.6           3.2
# 48            5.3           3.7
# 49            5.0           3.3

# %%
iris.iloc[:,0:2]
# Out:
#      sepallengthcm  sepalwidthcm
# 0              5.1           3.5
# 1              4.9           3.0
# 2              4.7           3.2
# 3              4.6           3.1
# 4              5.0           3.6
# ..             ...           ...
# 145            6.7           3.0
# 146            6.3           2.5
# 147            6.5           3.0
# 148            6.2           3.4
# 149            5.9           3.0
#
# [150 rows x 2 columns]

# %%
iris.T
# Out:
#                        0            1            2            3    \
# sepallengthcm          5.1          4.9          4.7          4.6
# sepalwidthcm           3.5          3.0          3.2          3.1
# petallengthcm          1.4          1.4          1.3          1.5
# petalwidthcm           0.2          0.2          0.2          0.2
# species        IRIS-SETOSA  IRIS-SETOSA  IRIS-SETOSA  IRIS-SETOSA
#
#                        4            5            6            7    \
# sepallengthcm          5.0          5.4          4.6          5.0
# sepalwidthcm           3.6          3.9          3.4          3.4
# petallengthcm          1.4          1.7          1.4          1.5
# petalwidthcm           0.2          0.4          0.3          0.2
# species        IRIS-SETOSA  IRIS-SETOSA  IRIS-SETOSA  IRIS-SETOSA
#
#                        8            9    ...             140             141  \
# sepallengthcm          4.4          4.9  ...             6.7             6.9
# ...

# %%
rownum=iris.shape[0]

# %%
rownum
# Out:
# 150

# %%
iris.iloc[rownum-6:]
# Out:
#      sepallengthcm  sepalwidthcm  petallengthcm  petalwidthcm         species
# 144            6.7           3.3            5.7           2.5  IRIS-VIRGINICA
# 145            6.7           3.0            5.2           2.3  IRIS-VIRGINICA
# 146            6.3           2.5            5.0           1.9  IRIS-VIRGINICA
# 147            6.5           3.0            5.2           2.0  IRIS-VIRGINICA
# 148            6.2           3.4            5.4           2.3  IRIS-VIRGINICA
# 149            5.9           3.0            5.1           1.8  IRIS-VIRGINICA

# %%
iris.dtypes
# Out:
# sepallengthcm    float64
# sepalwidthcm     float64
# petallengthcm    float64
# petalwidthcm     float64
# species           object
# dtype: object

# %%
iris.select_dtypes('float64')
# Out:
#      sepallengthcm  sepalwidthcm  petallengthcm  petalwidthcm
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 145            6.7           3.0            5.2           2.3
# 146            6.3           2.5            5.0           1.9
# 147            6.5           3.0            5.2           2.0
# 148            6.2           3.4            5.4           2.3
# 149            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]

# %%
iris.select_dtypes(include=['float64']).columns
# Out:
# Index(['sepallengthcm', 'sepalwidthcm', 'petallengthcm', 'petalwidthcm'], dtype='object')

# %%
iris.T
# Out:
#                        0            1            2            3    \
# sepallengthcm          5.1          4.9          4.7          4.6
# sepalwidthcm           3.5          3.0          3.2          3.1
# petallengthcm          1.4          1.4          1.3          1.5
# petalwidthcm           0.2          0.2          0.2          0.2
# species        IRIS-SETOSA  IRIS-SETOSA  IRIS-SETOSA  IRIS-SETOSA
#
#                        4            5            6            7    \
# sepallengthcm          5.0          5.4          4.6          5.0
# sepalwidthcm           3.6          3.9          3.4          3.4
# petallengthcm          1.4          1.7          1.4          1.5
# petalwidthcm           0.2          0.4          0.3          0.2
# species        IRIS-SETOSA  IRIS-SETOSA  IRIS-SETOSA  IRIS-SETOSA
#
#                        8            9    ...             140             141  \
# sepallengthcm          4.4          4.9  ...             6.7             6.9
# ...

# %%
iris.head()
# Out:
#    sepallengthcm  sepalwidthcm  petallengthcm  petalwidthcm      species
# 0            5.1           3.5            1.4           0.2  IRIS-SETOSA
# 1            4.9           3.0            1.4           0.2  IRIS-SETOSA
# 2            4.7           3.2            1.3           0.2  IRIS-SETOSA
# 3            4.6           3.1            1.5           0.2  IRIS-SETOSA
# 4            5.0           3.6            1.4           0.2  IRIS-SETOSA

# %%
iris['species'].unique()
# Out:
# array(['IRIS-SETOSA', 'IRIS-VERSICOLOR', 'IRIS-VIRGINICA'], dtype=object)

# %%
iris['species'].value_counts()
# Out:
# IRIS-SETOSA        50
# IRIS-VERSICOLOR    50
# IRIS-VIRGINICA     50
# Name: species, dtype: int64

# %%
iris.species.value_counts()
# Out:
# IRIS-SETOSA        50
# IRIS-VERSICOLOR    50
# IRIS-VIRGINICA     50
# Name: species, dtype: int64

# %%
iris['sepallengthcm'].sum()
# Out:
# 876.5

# %%
iris[['sepallengthcm','sepalwidthcm']].sum()
# Out:
# sepallengthcm    876.5
# sepalwidthcm     458.1
# dtype: float64

# %%
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers.readers:
#
# ...

# %%
import numpy as np

# %%
import pandas as pd

df = pd.DataFrame({
    '$name$': ['Ali#ce', 'Bobby@', 'Ca$r%l', 'D^a&n'],
    '!experience@': [11, 14, 16, 18],
    '^salary*': [175.1, 180.2, 190.3, 210.4],
})

df['$name$'] = df['$name$'].str.replace(r'\W', '', regex=True)

# %%
df
# Out:
#   $name$  !experience@  ^salary*
# 0  Alice            11     175.1
# 1  Bobby            14     180.2
# 2   Carl            16     190.3
# 3    Dan            18     210.4

# %%
import pandas as pd
import re
df = pd.DataFrame({
    '$name$': ['Ali#c_e', 'Bo_bby@', 'Ca$r%l', 'D^a&n'],
    '!experience@': [11, 14, 16, 18],
    '^salary*': [175.1, 180.2, 190.3, 210.4],
})

df['$name$'] = df['$name$'].str.replace(
    r'[^a-z0-9]',
    '',
    regex=True,
    flags=re.IGNORECASE
)
df
# Out:
#   $name$  !experience@  ^salary*
# 0  Alice            11     175.1
# 1  Bobby            14     180.2
# 2   Carl            16     190.3
# 3    Dan            18     210.4

# %%
import pandas as pd

df = pd.DataFrame({'score': ['A', 'B', 'C']})

df['score'].replace({'A': 1, 'B': 2, 'C': 3}, inplace=True)

print(df)
# Out:
#    score
# 0      1
# 1      2
# 2      3

# %%
import pandas as pd

df = pd.DataFrame({'age': ['25', '30', '35']})

df['age'] = df['age'].astype('int')

print(df)
# Out:
#    age
# 0   25
# 1   30
# 2   35

# %%
df = pd.DataFrame({'age': ['25', '30', '35','ABCD']})

df['age'] = pd.to_numeric(df['age'], errors='coerce')
df
# Out:
#     age
# 0  25.0
# 1  30.0
# 2  35.0
# 3   NaN

# %%
df = pd.DataFrame({'age': ['25', '30', '35','ABCD']})
df['age'] = df['age'].str.replace('ABCD', '24')
df['age'] = pd.to_numeric(df['age'], errors='coerce')

# %%
df
# Out:
#    age
# 0   25
# 1   30
# 2   35
# 3   24

# %%
df = pd.DataFrame({'age': ['25', '30', '35','ABCD'],'name':["A","B","C","D"]})

df['age'] = pd.to_numeric(df['age'], errors='coerce')
df
# Out:
#     age name
# 0  25.0    A
# 1  30.0    B
# 2  35.0    C
# 3   NaN    D

# %%
df[df['age'].isna()]
# Out:
# Int64Index([3], dtype='int64')

# %%
df['age'].isna()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# Name: age, dtype: bool

# %%
df[df['age'].isna()].index
# Out:
# Int64Index([3], dtype='int64')

# %%
df['age'].fillna(100)
# Out:
# 0     25.0
# 1     30.0
# 2     35.0
# 3    100.0
# Name: age, dtype: float64

# %%
df['age'].isna()

# %%
import pandas as pd

df = pd.DataFrame({
    'name': ['Ali#ce', 'Bobby@', 'Ca$r%l', 'D^a&n'],
    '!experience@': [11, 14, 16, 18],
    '^salary*': [175.1, 180.2, 190.3, 210.4],
})
replaceDict = {"[\#]+":'','[\@]+':'2'}

for k,v in replaceDict.items():
    df['name']=df['name'].str.replace(
    k,
    v,
    regex=True,
    flags=re.IGNORECASE
)

# %%
# Out:
#      name  !experience@  ^salary*
# 0   Alice            11     175.1
# 1  Bobby2            14     180.2
# 2  Ca$r%l            16     190.3
# 3   D^a&n            18     210.4

# %%
print (pd.to_datetime(pd.Series(['Jul 31, 2009','2010-01-10', '2-May-2023','2/May/23','2/5/2023','2/13/2023','13/2/2023'])))
# Out:
# 0   2009-07-31
# 1   2010-01-10
# 2   2023-05-02
# 3   2023-05-02
# 4   2023-02-05
# 5   2023-02-13
# 6   2023-02-13
# dtype: datetime64[ns]

# %%
iris
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-2975561be2ce> in <module>
# ----> 1 iris
#
# NameError: name 'iris' is not defined

# %%
iris =pd.read_csv("C://data/Iris.csv")

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris['Sepal']=iris['SepalLengthCm']+iris['SepalWidthCm']

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species  \
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
#
#    Sepal
# 0    8.6
# 1    7.9
# 2    7.9
# 3    7.7
# 4    8.6

# %%
iris.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000
#
#             Sepal
# count  150.000000
# mean     8.897333
# std      0.891718
# min      6.800000
# 25%      8.300000
# 50%      8.850000
# 75%      9.575000
# max     11.700000

# %%
iris['Sepal'].max()
# Out:
# 11.7

# %%
iris.loc[iris['Species']=='Iris-setosa','Species']='IRIS-SETOSA'

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  IRIS-SETOSA
# 1   2            4.9           3.0            1.4           0.2  IRIS-SETOSA
# 2   3            4.7           3.2            1.3           0.2  IRIS-SETOSA
# 3   4            4.6           3.1            1.5           0.2  IRIS-SETOSA
# 4   5            5.0           3.6            1.4           0.2  IRIS-SETOSA

# %%
iris['Species'].unique()
# Out:
# array(['IRIS-SETOSA', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       IRIS-SETOSA
# 1       IRIS-SETOSA
# 2       IRIS-SETOSA
# 3       IRIS-SETOSA
# 4       IRIS-SETOSA
# ..              ...
# ...

# %%
iris[(iris['Species']=="IRIS-SETOSA") | (iris['Species']=='Iris-virginica')]
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       IRIS-SETOSA
# 1       IRIS-SETOSA
# 2       IRIS-SETOSA
# 3       IRIS-SETOSA
# 4       IRIS-SETOSA
# ..              ...
# ...

# %%
iris[(iris['Species']=="IRIS-SETOSA") | (iris['Species']=='Iris-virginica')].iloc[10:50]
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 10  11            5.4           3.7            1.5           0.2  IRIS-SETOSA
# 11  12            4.8           3.4            1.6           0.2  IRIS-SETOSA
# 12  13            4.8           3.0            1.4           0.1  IRIS-SETOSA
# 13  14            4.3           3.0            1.1           0.1  IRIS-SETOSA
# 14  15            5.8           4.0            1.2           0.2  IRIS-SETOSA
# 15  16            5.7           4.4            1.5           0.4  IRIS-SETOSA
# 16  17            5.4           3.9            1.3           0.4  IRIS-SETOSA
# 17  18            5.1           3.5            1.4           0.3  IRIS-SETOSA
# 18  19            5.7           3.8            1.7           0.3  IRIS-SETOSA
# 19  20            5.1           3.8            1.5           0.3  IRIS-SETOSA
# 20  21            5.4           3.4            1.7           0.2  IRIS-SETOSA
# ...

# %%
iris =pd.read_csv("C://data/Iris.csv",dtype={"Species":"float64"})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# TypeError: Cannot cast array data from dtype('O') to dtype('float64') according to the rule 'safe'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-d01ca7369909> in <module>
# ----> 1 iris =pd.read_csv("C://data/Iris.csv",dtype={"Species":"float64"})
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
import pandas as pd

df = pd.DataFrame({
    'name': ['Ali#ce', 'Bobby@', 'Ca$r%l', 'D^a&n'],
    '!experience@': [11, 14, 16, 18],
    '^salary*': [175.1, 180.2, 190.3, 210.4],
})
replaceDict = {"[\#]+":'','[\@]+':'2'}

for k,v in replaceDict.items():
    df['name']=df['name'].str.replace(
    k,
    v,
    regex=True,
    flags=re.IGNORECASE
)
df.to_csv("C://training//day1//corrected.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-94-42da9d846054> in <module>
#      13     v,
#      14     regex=True,
# ---> 15     flags=re.IGNORECASE
#      16 )
#      17 df.to_csv("C://training//day1//corrected.csv")
#
# NameError: name 're' is not defined

# %%
help(pd.read_excel)
# Out:
# Help on function read_excel in module pandas.io.excel._base:
#
# read_excel(io, sheet_name=0, header=0, names=None, index_col=None, usecols=None, squeeze=False, dtype: 'DtypeArg | None' = None, engine=None, converters=None, true_values=None, false_values=None, skiprows=None, nrows=None, na_values=None, keep_default_na=True, na_filter=True, verbose=False, parse_dates=False, date_parser=None, thousands=None, comment=None, skipfooter=0, convert_float=None, mangle_dupe_cols=True, storage_options: 'StorageOptions' = None)
#     Read an Excel file into a pandas DataFrame.
#
#     Supports `xls`, `xlsx`, `xlsm`, `xlsb`, `odf`, `ods` and `odt` file extensions
#     read from a local filesystem or URL. Supports an option to read
#     a single sheet or a list of sheets.
#
#     Parameters
#     ----------
#     io : str, bytes, ExcelFile, xlrd.Book, path object, or file-like object
#         Any valid string path is acceptable. The string could be a URL. Valid
# ...

# %%
iris[iris['SepalWidthCm'] > 3.1].loc[2:5,'SepalLengthCm']=0
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
iris[iris['SepalWidthCm'] > 3.1].loc[2:5,'SepalLengthCm']
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       IRIS-SETOSA
# 1       IRIS-SETOSA
# 2       IRIS-SETOSA
# 3       IRIS-SETOSA
# 4       IRIS-SETOSA
# ..              ...
# ...

# %%
df2
# Out:
# 4    5.0
# 5    5.4
# 6    4.6
# Name: SepalLengthCm, dtype: float64

# %%
iris[iris['SepalWidthCm'] > 3.1].iloc[2:6,1]
# Out:
# 4    5.0
# 5    5.4
# 6    4.6
# 7    5.0
# Name: SepalLengthCm, dtype: float64

# %%
iris[iris['SepalWidthCm'] > 3.1].loc[2:6,'SepalLengthCm']=0
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
iris.loc[iris['Species']=='Iris-setosa','Species']='IRIS-SETOSA'

# %%
iris[iris['SepalWidthCm'] > 3.1].loc[2:6,'SepalLengthCm'].iloc[:]=0

# %%
iris[iris['SepalWidthCm'] > 3.1].loc[2:6]['SepalLengthCm']=0

# %%
iris.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
iris['index']=iris.index

# %%
iris.loc[(iris['SepalWidthCm']> 3.1) & (iris['index'].isin(list(range(2,5)))),'SepalLengthCm']=0

# %%
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            0.0           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            0.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species  index
# 0       IRIS-SETOSA      0
# 1       IRIS-SETOSA      1
# 2       IRIS-SETOSA      2
# 3       IRIS-SETOSA      3
# ...

# %%
resdf=iris.iloc[:,1:4]

# %%
resdf
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm
# 0              5.1           3.5            1.4
# 1              4.9           3.0            1.4
# 2              0.0           3.2            1.3
# 3              4.6           3.1            1.5
# 4              0.0           3.6            1.4
# ..             ...           ...            ...
# 145            6.7           3.0            5.2
# 146            6.3           2.5            5.0
# 147            6.5           3.0            5.2
# 148            6.2           3.4            5.4
# 149            5.9           3.0            5.1
#
# [150 rows x 3 columns]

# %%
iris.to_csv("C://training//day1//sampeliris.csv",index=False)

# %%
iris.to_excel("C://training//day1//sampleiris.xlsx",sheet_name="iris-jpmc")

# %%
iris.to_json("C://training//day1//sampel.json")

# %%
iris.to_html("C://training//day1//iris.html")

# %%
iris.to_parquet("C://training//day1//iris.parquet")

# %%
# %%time
iris_new = pd.read_parquet("C://training//day1//iris.parquet")
# Out:
# Wall time: 8.4 ms

# %%
# %%time
iris_new1=pd.read_excel("C://training//day1//sampleiris.xlsx")
# Out:
# Wall time: 1.15 s

# %%
iris_new2=pd.read_html("C://training//day1//iris.html")

# %%
iris_new2[0]
# Out:
#      Unnamed: 0   Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# 0             0    1            5.1           3.5            1.4
# 1             1    2            4.9           3.0            1.4
# 2             2    3            0.0           3.2            1.3
# 3             3    4            4.6           3.1            1.5
# 4             4    5            0.0           3.6            1.4
# ..          ...  ...            ...           ...            ...
# 145         145  146            6.7           3.0            5.2
# 146         146  147            6.3           2.5            5.0
# 147         147  148            6.5           3.0            5.2
# 148         148  149            6.2           3.4            5.4
# 149         149  150            5.9           3.0            5.1
#
#      PetalWidthCm         Species  index
# 0             0.2     IRIS-SETOSA      0
# 1             0.2     IRIS-SETOSA      1
# 2             0.2     IRIS-SETOSA      2
# ...

# %%
help(pd.read_html)
# Out:
# Help on function read_html in module pandas.io.html:
#
# read_html(io: 'FilePathOrBuffer', match: 'str | Pattern' = '.+', flavor: 'str | None' = None, header: 'int | Sequence[int] | None' = None, index_col: 'int | Sequence[int] | None' = None, skiprows: 'int | Sequence[int] | slice | None' = None, attrs: 'dict[str, str] | None' = None, parse_dates: 'bool' = False, thousands: 'str | None' = ',', encoding: 'str | None' = None, decimal: 'str' = '.', converters: 'dict | None' = None, na_values=None, keep_default_na: 'bool' = True, displayed_only: 'bool' = True) -> 'list[DataFrame]'
#     Read HTML tables into a ``list`` of ``DataFrame`` objects.
#
#     Parameters
#     ----------
#     io : str, path object or file-like object
#         A URL, a file-like object, or a raw string containing HTML. Note that
#         lxml only accepts the http, ftp and file url protocols. If you have a
#         URL that starts with ``'https'`` you might try removing the ``'s'``.
#
# ...

# %%
wikipedia=pd.read_html("https://en.wikipedia.org/wiki/India")

# %%
len(wikipedia)
# Out:
# 30

# %%
wikipedia[5]
# Out:
#                  0                                                  1
# 0        Overviews  Timeline Years Astronomy Clothing Coinage Econ...
# 1          Ancient  Stone Age Indus Valley civilization Vedic peri...
# 2  Middle Kingdoms                              Middle kingdoms Chola
# 3      Middle Ages  Medieval India Hoysala Pala Kakatiya Delhi Sul...
# 4     Early Modern         Mughals Marathas European trade Bengal War
# 5      Late modern  Colonial Princely state East India Company Pla...
# 6         Republic  Integration Non-Aligned Movement Five-Year Pla...
# 7     Contemporary  History of India (1947–present) Economic liber...

# %% [markdown]
# iris.head()

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
groupby = iris.groupby('Species')

# %%
groupby.agg({"SepalLengthCm":["min","max"],"PetalLengthCm":["sum","mean"]})
# Out:
#                 SepalLengthCm      PetalLengthCm
#                           min  max           sum   mean
# Species
# Iris-setosa               4.3  5.8          73.2  1.464
# Iris-versicolor           4.9  7.0         213.0  4.260
# Iris-virginica            4.9  7.9         277.6  5.552

# %%
import pandas as pd
import numpy as np

ipl_data = {'Team': ['Riders', 'Riders', 'Devils', 'Devils', 'Kings',
         'kings', 'Kings', 'Kings', 'Riders', 'Royals', 'Royals', 'Riders'],
         'Rank': [1, 2, 2, 3, 3,4 ,1 ,1,2 , 4,1,2],
         'Year': [2014,2015,2014,2015,2014,2015,2016,2017,2016,2014,2015,2017],
         'Points':[876,789,863,673,741,812,756,788,694,701,804,690]}
df = pd.DataFrame(ipl_data)

grouped = df.groupby(['Team','Year'])


grouped.agg({"Rank":["min","max"]})
# Out:
#             Rank
#              min max
# Team   Year
# Devils 2014    2   2
#        2015    3   3
# Kings  2014    3   3
#        2016    1   1
#        2017    1   1
# Riders 2014    1   1
#        2015    2   2
#        2016    2   2
#        2017    2   2
# Royals 2014    4   4
#        2015    1   1
# kings  2015    4   4

# %%
grouped.groups
# Out:
# {('Devils', 2014): [2], ('Devils', 2015): [3], ('Kings', 2014): [4], ('Kings', 2016): [6], ('Kings', 2017): [7], ('Riders', 2014): [0], ('Riders', 2015): [1], ('Riders', 2016): [8], ('Riders', 2017): [11], ('Royals', 2014): [9], ('Royals', 2015): [10], ('kings', 2015): [5]}

# %%
grouped.get_group((('Devils', 2014)))
# Out:
#      Team  Rank  Year  Points
# 2  Devils     2  2014     863

# %%
def filter1(no):
    return no > 2

# %%
filter2 = lambda no : no > 2

# %%
filter2(1)
# Out:
# False

# %%
filter2(99)
# Out:
# True

# %%
grouped = df.groupby('Team')
score = lambda x: (x - x.mean()) / x.std()*10
print ('score',grouped.transform(score))
##print (df.groupby('Team').filter(lambda x: len(x) >= 3))
##

# %%
help(df.groupby('Team').filter)
# Out:
# Help on method filter in module pandas.core.groupby.generic:
#
# filter(func, dropna=True, *args, **kwargs) method of pandas.core.groupby.generic.DataFrameGroupBy instance
#     Return a copy of a DataFrame excluding filtered elements.
#
#     Elements from groups are filtered if they do not satisfy the
#     boolean criterion specified by func.
#
#     Parameters
#     ----------
#     func : function
#         Function to apply to each subframe. Should return True or False.
#     dropna : Drop groups that do not pass the filter. True by default;
#         If False, groups that evaluate False are filled with NaNs.
#
#     Returns
#     -------
#     filtered : DataFrame
#
#     Notes
#     -----
#     Each subframe is endowed the attribute 'name' in case you need to know
#     which group you are working on.
#
#     Functions that mutate the passed object can produce unexpected
#     behavior or errors and are not supported. See :ref:`gotchas.udf-mutation`
#     for more details.
#
# ...

# %%
def filter3(x):
    return len(x) > 3
